# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('input/wtageinf.csv')
df
# Out:
#     Sex  Agemos         L          M         S         P3         P5  \
# 0     1     0.0  1.815151   3.530203  0.152385   2.355451   2.526904
# 1     1     0.5  1.547523   4.003106  0.146025   2.799549   2.964656
# 2     1     1.5  1.068796   4.879525  0.136479   3.614688   3.774849
# 3     1     2.5  0.695974   5.672889  0.129678   4.342341   4.503255
# 4     1     3.5  0.419815   6.391392  0.124717   4.992898   5.157412
# ..  ...     ...       ...        ...       ...        ...        ...
# 71    2    32.5 -0.955723  13.340229  0.115115  10.957219  11.209345
# 72    2    33.5 -0.974381  13.489134  0.116193  11.064747  11.320538
# 73    2    34.5 -0.991981  13.638774  0.117286  11.172248  11.431774
# 74    2    35.5 -1.008641  13.789365  0.118387  11.279999  11.543323
# 75    2    36.0 -1.016653  13.865074  0.118939  11.334045  11.599289
#
#           P10        P25        P50        P75        P90        P95  \
# ...

# %%
gk = df.groupby('Sex')

# %%
plt.figure(figsize=(8,6))
col = ['P3','P5','P10','P25','P50','P75','P90','P95','P97']
sns.lineplot(x='Agemos', y='value', hue='variable', data=pd.melt(gk.get_group(1), ['Agemos','Sex','L','M','S']))

# %%
plt.figure(figsize=(8,6))
col = ['P3','P5','P10','P25','P50','P75','P90','P95','P97']
sns.lineplot(x='Agemos', y='value', hue='variable', data=pd.melt(gk.get_group(2), ['Agemos','Sex','L','M','S']))

# %%
[ 0, 0, 1, 0, 0, 0 ], # [0,2]
[ 0, 0, 0, 1, 0, 0 ], # [1,3]
[ 0, 0, 0, 1, 1, 0 ] # [2,3] [2,4]
[ 0, 0 ,0 ,0 ,0 ,1 ] # [3,5]
[ 0, 0 ,0 ,0 ,0 ,1 ] # [4,5]
[ 0, 0 ,0 ,0 ,0 ,0 ]
